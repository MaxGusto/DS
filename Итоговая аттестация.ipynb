# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

df = pd.read_csv ('/content/drive/MyDrive/Colab Notebooks/ebw_data.csv')

# %%
X = df.drop(["Width", "Depth"], axis=1)
y = df[["Width", "Depth"]].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(start=10, stop=100, num=3)]

max_depth = [int(x) for x in np.linspace(5, 80, num=4)]

max_depth.append(None)
min_samples_leaf = [1, 3]

param_grid = {
    'n_estimators': n_estimators,
    'max_depth': max_depth,
    'min_samples_leaf': min_samples_leaf
              }
param_grid
# Out:
# {'n_estimators': [10, 55, 100],
#  'max_depth': [5, 30, 55, 80, None],
#  'min_samples_leaf': [1, 3]}

# %%
rf_random = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, verbose=3)
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END max_depth=5, min_samples_leaf=1, n_estimators=10;, score=0.918 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=1, n_estimators=10;, score=0.915 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=1, n_estimators=10;, score=0.885 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=1, n_estimators=10;, score=0.938 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=1, n_estimators=10;, score=0.927 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=1, n_estimators=55;, score=0.915 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=1, n_estimators=55;, score=0.921 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=1, n_estimators=55;, score=0.905 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=1, n_estimators=55;, score=0.909 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=1, n_estimators=55;, score=0.948 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.912 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.923 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.897 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.924 total time=   0.2s
# [CV 5/5] END max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.947 total time=   0.2s
# [CV 1/5] END max_depth=5, min_samples_leaf=3, n_estimators=10;, score=0.858 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=3, n_estimators=10;, score=0.881 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=3, n_estimators=10;, score=0.882 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=3, n_estimators=10;, score=0.840 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=3, n_estimators=10;, score=0.927 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=3, n_estimators=55;, score=0.882 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=3, n_estimators=55;, score=0.877 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=3, n_estimators=55;, score=0.876 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=3, n_estimators=55;, score=0.843 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=3, n_estimators=55;, score=0.926 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=3, n_estimators=100;, score=0.877 total time=   0.2s
# [CV 2/5] END max_depth=5, min_samples_leaf=3, n_estimators=100;, score=0.892 total time=   0.2s
# [CV 3/5] END max_depth=5, min_samples_leaf=3, n_estimators=100;, score=0.881 total time=   0.2s
# [CV 4/5] END max_depth=5, min_samples_leaf=3, n_estimators=100;, score=0.847 total time=   0.2s
# [CV 5/5] END max_depth=5, min_samples_leaf=3, n_estimators=100;, score=0.929 total time=   0.2s
# [CV 1/5] END max_depth=30, min_samples_leaf=1, n_estimators=10;, score=0.916 total time=   0.0s
# [CV 2/5] END max_depth=30, min_samples_leaf=1, n_estimators=10;, score=0.906 total time=   0.0s
# [CV 3/5] END max_depth=30, min_samples_leaf=1, n_estimators=10;, score=0.881 total time=   0.0s
# [CV 4/5] END max_depth=30, min_samples_leaf=1, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 5/5] END max_depth=30, min_samples_leaf=1, n_estimators=10;, score=0.937 total time=   0.0s
# [CV 1/5] END max_depth=30, min_samples_leaf=1, n_estimators=55;, score=0.914 total time=   0.1s
# [CV 2/5] END max_depth=30, min_samples_leaf=1, n_estimators=55;, score=0.916 total time=   0.1s
# [CV 3/5] END max_depth=30, min_samples_leaf=1, n_estimators=55;, score=0.883 total time=   0.1s
# [CV 4/5] END max_depth=30, min_samples_leaf=1, n_estimators=55;, score=0.925 total time=   0.1s
# [CV 5/5] END max_depth=30, min_samples_leaf=1, n_estimators=55;, score=0.940 total time=   0.1s
# [CV 1/5] END max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.906 total time=   0.2s
# [CV 2/5] END max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 3/5] END max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.883 total time=   0.2s
# [CV 4/5] END max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.935 total time=   0.2s
# [CV 5/5] END max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.940 total time=   0.2s
# [CV 1/5] END max_depth=30, min_samples_leaf=3, n_estimators=10;, score=0.876 total time=   0.0s
# [CV 2/5] END max_depth=30, min_samples_leaf=3, n_estimators=10;, score=0.887 total time=   0.0s
# [CV 3/5] END max_depth=30, min_samples_leaf=3, n_estimators=10;, score=0.880 total time=   0.0s
# [CV 4/5] END max_depth=30, min_samples_leaf=3, n_estimators=10;, score=0.838 total time=   0.0s
# [CV 5/5] END max_depth=30, min_samples_leaf=3, n_estimators=10;, score=0.905 total time=   0.0s
# [CV 1/5] END max_depth=30, min_samples_leaf=3, n_estimators=55;, score=0.880 total time=   0.1s
# [CV 2/5] END max_depth=30, min_samples_leaf=3, n_estimators=55;, score=0.873 total time=   0.1s
# [CV 3/5] END max_depth=30, min_samples_leaf=3, n_estimators=55;, score=0.876 total time=   0.1s
# [CV 4/5] END max_depth=30, min_samples_leaf=3, n_estimators=55;, score=0.831 total time=   0.1s
# [CV 5/5] END max_depth=30, min_samples_leaf=3, n_estimators=55;, score=0.925 total time=   0.1s
# [CV 1/5] END max_depth=30, min_samples_leaf=3, n_estimators=100;, score=0.881 total time=   0.1s
# [CV 2/5] END max_depth=30, min_samples_leaf=3, n_estimators=100;, score=0.884 total time=   0.1s
# [CV 3/5] END max_depth=30, min_samples_leaf=3, n_estimators=100;, score=0.883 total time=   0.1s
# [CV 4/5] END max_depth=30, min_samples_leaf=3, n_estimators=100;, score=0.842 total time=   0.1s
# [CV 5/5] END max_depth=30, min_samples_leaf=3, n_estimators=100;, score=0.927 total time=   0.1s
# [CV 1/5] END max_depth=55, min_samples_leaf=1, n_estimators=10;, score=0.901 total time=   0.0s
# [CV 2/5] END max_depth=55, min_samples_leaf=1, n_estimators=10;, score=0.912 total time=   0.0s
# [CV 3/5] END max_depth=55, min_samples_leaf=1, n_estimators=10;, score=0.883 total time=   0.0s
# [CV 4/5] END max_depth=55, min_samples_leaf=1, n_estimators=10;, score=0.929 total time=   0.0s
# [CV 5/5] END max_depth=55, min_samples_leaf=1, n_estimators=10;, score=0.933 total time=   0.0s
# [CV 1/5] END max_depth=55, min_samples_leaf=1, n_estimators=55;, score=0.909 total time=   0.1s
# [CV 2/5] END max_depth=55, min_samples_leaf=1, n_estimators=55;, score=0.918 total time=   0.1s
# [CV 3/5] END max_depth=55, min_samples_leaf=1, n_estimators=55;, score=0.889 total time=   0.1s
# [CV 4/5] END max_depth=55, min_samples_leaf=1, n_estimators=55;, score=0.929 total time=   0.1s
# [CV 5/5] END max_depth=55, min_samples_leaf=1, n_estimators=55;, score=0.941 total time=   0.1s
# [CV 1/5] END max_depth=55, min_samples_leaf=1, n_estimators=100;, score=0.906 total time=   0.1s
# [CV 2/5] END max_depth=55, min_samples_leaf=1, n_estimators=100;, score=0.927 total time=   0.1s
# [CV 3/5] END max_depth=55, min_samples_leaf=1, n_estimators=100;, score=0.881 total time=   0.1s
# [CV 4/5] END max_depth=55, min_samples_leaf=1, n_estimators=100;, score=0.927 total time=   0.1s
# [CV 5/5] END max_depth=55, min_samples_leaf=1, n_estimators=100;, score=0.939 total time=   0.1s
# [CV 1/5] END max_depth=55, min_samples_leaf=3, n_estimators=10;, score=0.876 total time=   0.0s
# [CV 2/5] END max_depth=55, min_samples_leaf=3, n_estimators=10;, score=0.876 total time=   0.0s
# [CV 3/5] END max_depth=55, min_samples_leaf=3, n_estimators=10;, score=0.882 total time=   0.0s
# [CV 4/5] END max_depth=55, min_samples_leaf=3, n_estimators=10;, score=0.834 total time=   0.0s
# [CV 5/5] END max_depth=55, min_samples_leaf=3, n_estimators=10;, score=0.932 total time=   0.0s
# [CV 1/5] END max_depth=55, min_samples_leaf=3, n_estimators=55;, score=0.877 total time=   0.1s
# [CV 2/5] END max_depth=55, min_samples_leaf=3, n_estimators=55;, score=0.886 total time=   0.1s
# [CV 3/5] END max_depth=55, min_samples_leaf=3, n_estimators=55;, score=0.871 total time=   0.1s
# [CV 4/5] END max_depth=55, min_samples_leaf=3, n_estimators=55;, score=0.833 total time=   0.1s
# [CV 5/5] END max_depth=55, min_samples_leaf=3, n_estimators=55;, score=0.926 total time=   0.1s
# [CV 1/5] END max_depth=55, min_samples_leaf=3, n_estimators=100;, score=0.877 total time=   0.1s
# [CV 2/5] END max_depth=55, min_samples_leaf=3, n_estimators=100;, score=0.881 total time=   0.1s
# [CV 3/5] END max_depth=55, min_samples_leaf=3, n_estimators=100;, score=0.879 total time=   0.1s
# [CV 4/5] END max_depth=55, min_samples_leaf=3, n_estimators=100;, score=0.852 total time=   0.1s
# [CV 5/5] END max_depth=55, min_samples_leaf=3, n_estimators=100;, score=0.930 total time=   0.1s
# [CV 1/5] END max_depth=80, min_samples_leaf=1, n_estimators=10;, score=0.907 total time=   0.0s
# [CV 2/5] END max_depth=80, min_samples_leaf=1, n_estimators=10;, score=0.915 total time=   0.0s
# [CV 3/5] END max_depth=80, min_samples_leaf=1, n_estimators=10;, score=0.881 total time=   0.0s
# [CV 4/5] END max_depth=80, min_samples_leaf=1, n_estimators=10;, score=0.928 total time=   0.0s
# [CV 5/5] END max_depth=80, min_samples_leaf=1, n_estimators=10;, score=0.930 total time=   0.0s
# [CV 1/5] END max_depth=80, min_samples_leaf=1, n_estimators=55;, score=0.905 total time=   0.1s
# [CV 2/5] END max_depth=80, min_samples_leaf=1, n_estimators=55;, score=0.925 total time=   0.1s
# [CV 3/5] END max_depth=80, min_samples_leaf=1, n_estimators=55;, score=0.881 total time=   0.1s
# [CV 4/5] END max_depth=80, min_samples_leaf=1, n_estimators=55;, score=0.938 total time=   0.1s
# [CV 5/5] END max_depth=80, min_samples_leaf=1, n_estimators=55;, score=0.941 total time=   0.1s
# [CV 1/5] END max_depth=80, min_samples_leaf=1, n_estimators=100;, score=0.910 total time=   0.1s
# [CV 2/5] END max_depth=80, min_samples_leaf=1, n_estimators=100;, score=0.924 total time=   0.1s
# [CV 3/5] END max_depth=80, min_samples_leaf=1, n_estimators=100;, score=0.885 total time=   0.1s
# [CV 4/5] END max_depth=80, min_samples_leaf=1, n_estimators=100;, score=0.936 total time=   0.1s
# [CV 5/5] END max_depth=80, min_samples_leaf=1, n_estimators=100;, score=0.943 total time=   0.1s
# [CV 1/5] END max_depth=80, min_samples_leaf=3, n_estimators=10;, score=0.863 total time=   0.0s
# [CV 2/5] END max_depth=80, min_samples_leaf=3, n_estimators=10;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=80, min_samples_leaf=3, n_estimators=10;, score=0.874 total time=   0.0s
# [CV 4/5] END max_depth=80, min_samples_leaf=3, n_estimators=10;, score=0.841 total time=   0.0s
# [CV 5/5] END max_depth=80, min_samples_leaf=3, n_estimators=10;, score=0.915 total time=   0.0s
# [CV 1/5] END max_depth=80, min_samples_leaf=3, n_estimators=55;, score=0.879 total time=   0.1s
# [CV 2/5] END max_depth=80, min_samples_leaf=3, n_estimators=55;, score=0.882 total time=   0.1s
# [CV 3/5] END max_depth=80, min_samples_leaf=3, n_estimators=55;, score=0.876 total time=   0.1s
# [CV 4/5] END max_depth=80, min_samples_leaf=3, n_estimators=55;, score=0.833 total time=   0.1s
# [CV 5/5] END max_depth=80, min_samples_leaf=3, n_estimators=55;, score=0.931 total time=   0.1s
# [CV 1/5] END max_depth=80, min_samples_leaf=3, n_estimators=100;, score=0.879 total time=   0.1s
# [CV 2/5] END max_depth=80, min_samples_leaf=3, n_estimators=100;, score=0.882 total time=   0.1s
# [CV 3/5] END max_depth=80, min_samples_leaf=3, n_estimators=100;, score=0.881 total time=   0.1s
# [CV 4/5] END max_depth=80, min_samples_leaf=3, n_estimators=100;, score=0.830 total time=   0.1s
# [CV 5/5] END max_depth=80, min_samples_leaf=3, n_estimators=100;, score=0.932 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, n_estimators=10;, score=0.901 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, n_estimators=10;, score=0.919 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, n_estimators=10;, score=0.885 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, n_estimators=10;, score=0.927 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, n_estimators=10;, score=0.937 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, n_estimators=55;, score=0.908 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, n_estimators=55;, score=0.925 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, n_estimators=55;, score=0.891 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, n_estimators=55;, score=0.934 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, n_estimators=55;, score=0.943 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.904 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.926 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.882 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.934 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.943 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=3, n_estimators=10;, score=0.878 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=3, n_estimators=10;, score=0.862 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=3, n_estimators=10;, score=0.874 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=3, n_estimators=10;, score=0.803 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=3, n_estimators=10;, score=0.915 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=3, n_estimators=55;, score=0.873 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=3, n_estimators=55;, score=0.877 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=3, n_estimators=55;, score=0.876 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=3, n_estimators=55;, score=0.815 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=3, n_estimators=55;, score=0.927 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=3, n_estimators=100;, score=0.873 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=3, n_estimators=100;, score=0.885 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=3, n_estimators=100;, score=0.875 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=3, n_estimators=100;, score=0.840 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=3, n_estimators=100;, score=0.930 total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 30, 55, 80, None],
#                          'min_samples_leaf': [1, 3],
#                          'n_estimators': [10, 55, 100]},
#              verbose=3)

# %%
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

m = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
m
# Out:
# 0.07258246627952546

# %%
np.array(y_pred.mean(axis=0))
# Out:
# array([1.96805832, 1.20324185])

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(rf_random, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model.predict(X_test)
# Out:
# array([[1.9789009 , 0.96647697],
#        [1.9789009 , 0.96647697],
#        [1.77869521, 1.22402294],
#        [1.75382893, 1.11798585],
#        [2.52094212, 1.50910138],
#        [1.77869521, 1.22402294],
#        [2.49638706, 1.69240651],
#        [1.77869521, 1.22402294],
#        [2.09972095, 0.83645976],
#        [1.76887753, 1.28214691],
#        [1.77869521, 1.22402294]])

# %%
np.array(y_pred)
# Out:
# array([[1.97429   , 0.95981667],
#        [1.97429   , 0.95981667],
#        [1.78165727, 1.21807539],
#        [1.70687306, 1.09583413],
#        [2.52035558, 1.5087785 ],
#        [1.78165727, 1.21807539],
#        [2.49391905, 1.70155714],
#        [1.78165727, 1.21807539],
#        [2.09075143, 0.83465381],
#        [1.76153333, 1.3029019 ],
#        [1.78165727, 1.21807539]])

# %%
import joblib

joblib.dump(rf_random.best_estimator_, 'final_test.pkl', compress = 1)
# Out:
# ['final_test.pkl']

# %%
joblib.load("final_test.pkl")
# Out:
# RandomForestRegressor(max_depth=5)
